# %%
from gamma_simulator import gamma_simulator

# %%
    simulator = gamma_simulator()
    s = simulator.generate_signal()
    simulator.verbose_info()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Discrete-time parameters are used!
# Signal length : 1024 samples
# Number of events: 92 (randomly generated)
# Activity 0.100 event per sample and actual activity is 0.090 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 100
# Shape parameters: tau1 = 2±0.1 and tau2 = 10±0.1
# Each shape has a maximum length of 61.800 samples rounded to 61 samples
# Rise time is 2.682 samples and fall time is 59.118 samples
# Duty cycle is given by 6.18 with theoretical pile-up probability of 0.998
# Actual pile-up probability is 0.989 with 1 non-pile-up events out of 92 events
# Noise level: ±0.01 per sample
# Measured SNR: 78.15 dB
# Random seed is not defined

# %%
    simulator = gamma_simulator(verbose=True,
                                verbose_plots=True,
                                source={'name': ['Co-60', 'I-125'], 'weights': [1, 2]},
                                signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                                fs=10e6,
                                lambda_value=1e4,
                                dict_shape_params={'tau1_mean': 1e-7,  # continuous-time parameters measured in seconds
                                                   'tau1_std': 1e-9,
                                                   'tau2_mean': 1e-5,
                                                   'tau2_std': 1e-7},
                                noise_unit='std',
                                noise=1e-3,
                                dict_size=10,
                                seed=42)
    s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for ['Co-60', 'I-125'] source
# Weights are [1 2]
# Energy spectrum between 0.19 and 3330.59 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (1.00 samples) and tau2 = 1e-05 sec ±1.000e-07 (100.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 66.26 dB
# Pre-defined random seed is used: 42

# %%
    simulator = gamma_simulator(verbose=True,
                                verbose_plots=True,
                                source={'name': 'Co-60', 'weights': 1},
                                signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                                fs=10e6,
                                lambda_value=1e4,
                                dict_shape_params={'tau1_mean': 1e-7,  # continuous-time parameters measured in seconds
                                                   'tau1_std': 1e-9,
                                                   'tau2_mean': 1e-5,
                                                   'tau2_std': 1e-7},
                                noise_unit='std',
                                noise=1e-3,
                                dict_size=10,
                                seed=42)
    s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (1.00 samples) and tau2 = 1e-05 sec ±1.000e-07 (100.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 64.97 dB
# Pre-defined random seed is used: 42

# %%
simulator = gamma_simulator(
                            dict_type='gamma_shape'
                            )
s = simulator.generate_signal()
simulator.verbose_info()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Discrete-time parameters are used!
# Signal length : 1024 samples
# Number of events: 80 (randomly generated)
# Activity 0.100 event per sample and actual activity is 0.078 events per sample
# Shape model: gamma_shape
# Number of gamma_shape shapes in the dictionary: 100
# Shape parameters: tau1 = 0.1±0.001 and tau2 = 0.1±0.001
# Each shape has a maximum length of 61.800 samples rounded to 61 samples
# Rise time is 1.000 samples and fall time is 60.800 samples
# Duty cycle is given by 6.18 with theoretical pile-up probability of 0.998
# Actual pile-up probability is 0.988 with 1 non-pile-up events out of 80 events
# Noise level: ±0.01 per sample
# Measured SNR: 76.74 dB
# Random seed is not defined

# %%
simulator = gamma_simulator(verbose=True,
                            verbose_plots=True,
                            dict_type='gamma_shape'
                            )
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Discrete-time parameters are used!
# Signal length : 1024 samples
# Number of events: 117 (randomly generated)
# Activity 0.100 event per sample and actual activity is 0.114 events per sample
# Shape model: gamma_shape
# Number of gamma_shape shapes in the dictionary: 100
# Shape parameters: tau1 = 0.1±0.001 and tau2 = 0.1±0.001
# Each shape has a maximum length of 61.800 samples rounded to 61 samples
# Rise time is 1.000 samples and fall time is 60.800 samples
# Duty cycle is given by 6.18 with theoretical pile-up probability of 0.998
# Actual pile-up probability is 0.991 with 1 non-pile-up events out of 117 events
# Noise level: ±0.01 per sample
# Measured SNR: 79.09 dB
# Random seed is not defined

# %%
simulator = gamma_simulator(verbose=True,
                            verbose_plots=True,
                            dict_type='gamma_shape',
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_shape_params={'tau1_mean': 0.1,  # continuous-time parameters measured in seconds
                                               'tau1_std': 0.001,
                                               'tau2_mean': 1e5,
                                               'tau2_std': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: gamma_shape
# Number of gamma_shape shapes in the dictionary: 10
# Shape parameters: tau1 = 0.1 sec ±1.000e-03 (1000000.00 samples) and tau2 = 100000.0 sec ±1.000e+03 (1000000000000.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 1.000e-06 sec and fall time is 6.080e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 64.43 dB
# Pre-defined random seed is used: 42

# %%
simulator = gamma_simulator(verbose=True,
                            verbose_plots=True,
                            dict_type='gamma_shape',
                            source={'name': ['Co-60', 'I-125'], 'weights': [1, 2]},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_shape_params={'tau1_mean': 0.1,  # continuous-time parameters measured in seconds
                                               'tau1_std': 0.001,
                                               'tau2_mean': 1e5,
                                               'tau2_std': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for ['Co-60', 'I-125'] source
# Weights are [1 2]
# Energy spectrum between 0.19 and 3330.59 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: gamma_shape
# Number of gamma_shape shapes in the dictionary: 10
# Shape parameters: tau1 = 0.1 sec ±1.000e-03 (1000000.00 samples) and tau2 = 100000.0 sec ±1.000e+03 (1000000000000.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 1.000e-06 sec and fall time is 6.080e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 65.70 dB
# Pre-defined random seed is used: 42
