# %%
#test default
#for double_exp
#test single source 
#test fs,lambda_balue, noise
#test mult_sources
#then do the same thing for gamma

# %%
from gamma_simulator import gamma_simulator

simulator = gamma_simulator()
s = simulator.generate_signal()
simulator.verbose_info()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Discrete-time parameters are used!
# Signal length : 1024 samples
# Number of events: 99 (randomly generated)
# Activity 0.100 event per sample and actual activity is 0.097 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 100
# Shape parameters:  1.1±0.001 and 0.1±0.001
# Each shape has a maximum length of 55.350 samples rounded to 55 samples
# Rise time is 11.000 samples and fall time is 44.350 samples
# Duty cycle is given by 5.53 with theoretical pile-up probability of 0.996
# Actual pile-up probability is 0.970 with 3 non-pile-up events out of 99 events
# Noise level: ±0.01 per sample
# Measured SNR: 77.37 dB
# Random seed is not defined

# %%
# #  about default
simulator = gamma_simulator(verbose=True,
                                verbose_plots={'signal': True},)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Discrete-time parameters are used!
# Signal length : 1024 samples
# Number of events: 87 (randomly generated)
# Activity 0.100 event per sample and actual activity is 0.085 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 100
# Shape parameters: tau1 = 2±0.1 and tau2 = 10±0.1
# Each shape has a maximum length of 61.800 samples rounded to 61 samples
# Rise time is 2.682 samples and fall time is 59.118 samples
# Duty cycle is given by 6.18 with theoretical pile-up probability of 0.998
# Actual pile-up probability is 0.977 with 2 non-pile-up events out of 87 events
# Noise level: ±0.01 per sample
# Measured SNR: 77.47 dB
# Random seed is not defined

# %%
    simulator = gamma_simulator(verbose=True,
                                verbose_plots={'shapes': True, 'signal': True},
                                dict_type='gamma'
                                )
    s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Discrete-time parameters are used!
# Signal length : 1024 samples
# Number of events: 104 (randomly generated)
# Activity 0.100 event per sample and actual activity is 0.102 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 100
# Shape parameters:  1.1±0.001 and 0.1±0.001
# Each shape has a maximum length of 55.350 samples rounded to 55 samples
# Rise time is 11.000 samples and fall time is 44.350 samples
# Duty cycle is given by 5.53 with theoretical pile-up probability of 0.996
# Actual pile-up probability is 0.990 with 1 non-pile-up events out of 104 events
# Noise level: ±0.01 per sample
# Measured SNR: 78.76 dB
# Random seed is not defined

# %%
# # for double_exponential
# # about single source
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_type='double_exponential',
                            dict_shape_params={'mean1': 1e-7,  # continuous-time parameters measured in seconds
                                               'std1': 1e-9,
                                               'mean2': 1e-5,
                                               'std2': 1e-7},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (1.00 samples) and tau2 = 1e-05 sec ±1.000e-07 (100.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 64.97 dB
# Pre-defined random seed is used: 42

# %%
# # about single source and fs
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e7,
                            lambda_value=1e4,
                            dict_type='double_exponential',
                            dict_shape_params={'mean1': 1e-7,  # continuous-time parameters measured in seconds
                                               'std1': 1e-9,
                                               'mean2': 1e-5,
                                               'std2': 1e-7},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 100000000.0 samples per second
# Signal length is 1 sec that are 100000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-04 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (10.00 samples) and tau2 = 1e-05 sec ±1.000e-07 (1000.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 6180 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 44.97 dB
# Pre-defined random seed is used: 42

# %%
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e5,
                            lambda_value=1e4,
                            dict_type='double_exponential',
                            dict_shape_params={'mean1': 1e-7,  # continuous-time parameters measured in seconds
                                               'std1': 1e-9,
                                               'mean2': 1e-5,
                                               'std2': 1e-7},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 1000000.0 samples per second
# Signal length is 1 sec that are 1000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-02 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (0.10 samples) and tau2 = 1e-05 sec ±1.000e-07 (10.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 61 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.465 with 5479 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 84.98 dB
# Pre-defined random seed is used: 42

# %%
# # about single source and lambda_value
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e3,
                            dict_type='double_exponential',
                            dict_shape_params={'mean1': 1e-7,  # continuous-time parameters measured in seconds
                                               'std1': 1e-9,
                                               'mean2': 1e-5,
                                               'std2': 1e-7},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 1021 (randomly generated)
# Activity 1000.000 event per second and actual activity is 1021.000 events per second
# Normalized lambda value: 1.000e-04 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (1.00 samples) and tau2 = 1e-05 sec ±1.000e-07 (100.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.06 with theoretical pile-up probability of 0.060
# Actual pile-up probability is 0.064 with 956 non-pile-up events out of 1021 events
# Noise level: ±0.001 per sample
# Measured SNR: 54.89 dB
# Pre-defined random seed is used: 42

# %%
# # about single source and noise
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_type='double_exponential',
                            dict_shape_params={'mean1': 1e-7,  # continuous-time parameters measured in seconds
                                               'std1': 1e-9,
                                               'mean2': 1e-5,
                                               'std2': 1e-7},
                            noise_unit='snr',
                            noise=40,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (1.00 samples) and tau2 = 1e-05 sec ±1.000e-07 (100.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: 40 dB
# Measured SNR: 40.00 dB
# Pre-defined random seed is used: 42

# %%
# # mult_sources
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': ['Co-60', 'I-125'], 'weights': [1, 2]},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_type='double_exponential',
                            dict_shape_params={'mean1': 1e-7,  # continuous-time parameters measured in seconds
                                               'std1': 1e-9,
                                               'mean2': 1e-5,
                                               'std2': 1e-7},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for ['Co-60', 'I-125'] source
# Weights are [1 2]
# Energy spectrum between 0.19 and 3330.59 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (1.00 samples) and tau2 = 1e-05 sec ±1.000e-07 (100.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 618 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.470 with 5424 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 66.26 dB
# Pre-defined random seed is used: 42

# %%
# # mult_changes,fs, noise
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': ['Co-60', 'I-125'], 'weights': [1, 2]},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e5,
                            lambda_value=1e4,
                            dict_type='double_exponential',
                            dict_shape_params={'mean1': 1e-7,  # continuous-time parameters measured in seconds
                                               'std1': 1e-9,
                                               'mean2': 1e-5,
                                               'std2': 1e-7},
                            noise_unit='snr',
                            noise=40,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for ['Co-60', 'I-125'] source
# Weights are [1 2]
# Energy spectrum between 0.19 and 3330.59 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 1000000.0 samples per second
# Signal length is 1 sec that are 1000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-02 events per sample
# Shape model: double_exponential
# Number of double_exponential shapes in the dictionary: 10
# Shape parameters: tau1 = 1e-07 sec ±1.000e-09 (0.10 samples) and tau2 = 1e-05 sec ±1.000e-07 (10.00 samples)
# Each shape has a maximum length of 6.180e-05 sec that are 61 samples
# Rise time is 4.560e-07 sec and fall time is 6.134e-05 sec
# Duty cycle is given by 0.62 with theoretical pile-up probability of 0.461
# Actual pile-up probability is 0.465 with 5479 non-pile-up events out of 10236 events
# Noise level: 40 dB
# Measured SNR: 40.00 dB
# Pre-defined random seed is used: 42

# %%
# # for gamma
    # # about single source
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 553 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.55 with theoretical pile-up probability of 0.425
# Actual pile-up probability is 0.432 with 5812 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 64.45 dB
# Pre-defined random seed is used: 42

# %%
# # about single source and fs
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e7,
                            lambda_value=1e4,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 100000000.0 samples per second
# Signal length is 1 sec that are 100000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-04 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 5534 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.55 with theoretical pile-up probability of 0.425
# Actual pile-up probability is 0.432 with 5809 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 44.45 dB
# Pre-defined random seed is used: 42

# %%
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e5,
                            lambda_value=1e4,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 1000000.0 samples per second
# Signal length is 1 sec that are 1000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-02 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 55 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.55 with theoretical pile-up probability of 0.425
# Actual pile-up probability is 0.431 with 5825 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 84.46 dB
# Pre-defined random seed is used: 42

# %%
# # about single source and lambda_value
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e3,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 1021 (randomly generated)
# Activity 1000.000 event per second and actual activity is 1021.000 events per second
# Normalized lambda value: 1.000e-04 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 553 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.06 with theoretical pile-up probability of 0.054
# Actual pile-up probability is 0.059 with 961 non-pile-up events out of 1021 events
# Noise level: ±0.001 per sample
# Measured SNR: 54.35 dB
# Pre-defined random seed is used: 42

# %%
# # about single source and noise
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='snr',
                            noise=100,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 553 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.55 with theoretical pile-up probability of 0.425
# Actual pile-up probability is 0.432 with 5812 non-pile-up events out of 10236 events
# Noise level: 100 dB
# Measured SNR: 100.00 dB
# Pre-defined random seed is used: 42

# %%
# # mult_sources
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': ['Co-60', 'I-125'], 'weights': [1, 2]},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e6,
                            lambda_value=1e4,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for ['Co-60', 'I-125'] source
# Weights are [1 2]
# Energy spectrum between 0.19 and 3330.59 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 10000000.0 samples per second
# Signal length is 1 sec that are 10000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-03 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 553 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.55 with theoretical pile-up probability of 0.425
# Actual pile-up probability is 0.432 with 5812 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 65.72 dB
# Pre-defined random seed is used: 42

# %%
# # mult_changes,fs, noise
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'shapes': True, 'signal': True},
                            source={'name': ['Co-60', 'I-125'], 'weights': [1, 2]},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e5,
                            lambda_value=1e4,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='snr',
                            noise=40,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for ['Co-60', 'I-125'] source
# Weights are [1 2]
# Energy spectrum between 0.19 and 3330.59 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 1000000.0 samples per second
# Signal length is 1 sec that are 1000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-02 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 55 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.55 with theoretical pile-up probability of 0.425
# Actual pile-up probability is 0.431 with 5825 non-pile-up events out of 10236 events
# Noise level: 40 dB
# Measured SNR: 40.00 dB
# Pre-defined random seed is used: 42

# %%
## test spectrum
simulator = gamma_simulator(verbose=True,
                            verbose_plots={'spectrum': True, 'signal': True},
                            source={'name': 'Co-60', 'weights': 1},
                            signal_len=1,  # "analog" signal of 1 second that are 1e7 samples
                            fs=10e5,
                            lambda_value=1e4,
                            dict_type='gamma',
                            dict_shape_params={'mean1':  1.1,  # continuous-time parameters measured in seconds
                                               'std1': 0.001,
                                               'mean2': 1e5,
                                               'std2': 1e3},
                            noise_unit='std',
                            noise=1e-3,
                            dict_size=10,
                            seed=42)
s = simulator.generate_signal()
# Out:
# -- General information ------------------------------------------
# Loaded spectrum for Co-60 source
# Energy spectrum between 0.08 and 1665.23 keV with 8192 bins
# Shapes are NOT allowed to exceed the signal boundaries
# Sampling frequency: 1000000.0 samples per second
# Signal length is 1 sec that are 1000000 samples
# Events: 10236 (randomly generated)
# Activity 10000.000 event per second and actual activity is 10236.000 events per second
# Normalized lambda value: 1.000e-02 events per sample
# Shape model: gamma
# Number of gamma shapes in the dictionary: 10
# Shape parameters: alpha = 1.1 ±1.000e-03 and beta = 100000.0 ±1.000e+03
# Each shape has a maximum length of 5.535e-05 sec that are 55 samples
# Rise time is 1.100e-05 sec and fall time is 4.435e-05 sec
# Duty cycle is given by 0.55 with theoretical pile-up probability of 0.425
# Actual pile-up probability is 0.431 with 5825 non-pile-up events out of 10236 events
# Noise level: ±0.001 per sample
# Measured SNR: 84.46 dB
# Pre-defined random seed is used: 42
